# %%
# .env file
PINECONE_API_KEY= 51300079-39db-441d-92e5-28c066dd49eb
HUGGINGFACE_API_KEY= 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
# Out:
#   File "<ipython-input-2-be9e2d316703>", line 2
#     PINECONE_API_KEY= 51300079-39db-441d-92e5-28c066dd49eb
#                                 ^
# SyntaxError: invalid decimal literal

# %%
# Step 1: Install python-dotenv (if not already)
# !pip install python-dotenv

# Step 2: Write your .env file inside the Colab environment
with open(".env", "w") as f:
    f.write("""PINECONE_API_KEY=51300079-39db-441d-92e5-28c066dd49eb
HUGGINGFACE_API_KEY=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""")

# Step 3: Load environment variables
import os
from dotenv import load_dotenv

load_dotenv()

# Step 4: Access your variables
pinecone_key = os.getenv("PINECONE_API_KEY")
huggingface_key = os.getenv("HUGGINGFACE_API_KEY")

print("Pinecone Key:", pinecone_key)
print("Huggingface Key:", huggingface_key)
# Out:
# ...
# Pinecone Key: 51300079-39db-441d-92e5-28c066dd49eb
# Huggingface Key: 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

# %%
# create a file called main.py, and create an empty class called Chatbot inside it.
# This class is going to be called when we implement the frontend UI.
# For now, just create the class without adding any more code to it.

# main.py (this is for vs code)

class Chatbot:
    pass

# %%
# Create main.py file with an empty Chatbot class (this is for google collab)
with open("main.py", "w") as f:
    f.write("""class Chatbot:
    pass
""")
