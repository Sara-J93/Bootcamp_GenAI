# %%
# Challenge Description:
# Scenario: You are a data analyst working with a dataset of global weather. Your task is to analyze temperature trends and visualize the results.

# Tasks:

# 1. Data Preparation:

# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.

# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities.
# The temperatures should range from -5 to 35 degrees.

# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.
# 2. Data Analysis:

# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.

# Calculate the annual average temperature for each city.

# Identify the city with the highest and lowest average temperature for the year.
# 3. Data Visualization:

# %%
import numpy as np
import pandas as pd

# Generate synthetic temperature data for 10 cities over 12 months
temperature_data = np.random.uniform(low=-5, high=35, size=(10, 12))

# Display the first few rows of the generated data
print(temperature_data)
# Out:
# [[18.3408022  28.60074304 31.48133089 33.14358175 33.38362513 15.45994269
#   29.16759549  3.48864677 21.64691333 20.92930261  2.71492831 -2.24705629]
#  [27.28904348 23.10698829 14.35182426 26.92273355 20.22166846 15.67886939
#   33.98110133 23.17083939 17.62045514 -3.96345161 34.98578541 17.2562812 ]
#  [13.56579254 11.51716348 -2.03778394 29.49571238  4.58566545 27.78078099
#   11.86553874 17.51180649  5.25894665 25.82538703 18.9980703  -1.57358496]
#  [ 8.69142716 10.60886995 30.15260559  4.95556608 10.53562997  8.30697223
#   22.99570535  7.67413639 13.56621988 17.41658548 -4.92310664 12.00448394]
#  [11.67851105 22.07931446 18.00099589 14.23954488 12.0279923  -2.39661875
#   16.68651519 28.36793814 20.5753086  30.90126447 13.07424499 -0.48375571]
#  [ 6.64740352 27.59192677 33.78548648 30.42452423 22.13513729 33.54132413
#   33.53437406 32.24514117 30.79247117 27.96445787  8.55072065 -0.04418077]
#  [31.70714896 23.05108728 23.32101021 20.10714844  0.0765721   4.1255575
# ...

# %%
# Creating DataFrame

# City names and month names
cities = ['City1', 'City2', 'City3', 'City4', 'City5', 'City6', 'City7', 'City8', 'City9', 'City10']
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Create DataFrame using the synthetic data
df = pd.DataFrame(temperature_data, index=cities, columns=months)

# Display the DataFrame
print(df)
# Out:
#               Jan        Feb        Mar        Apr        May        Jun  \
# City1   18.340802  28.600743  31.481331  33.143582  33.383625  15.459943
# City2   27.289043  23.106988  14.351824  26.922734  20.221668  15.678869
# City3   13.565793  11.517163  -2.037784  29.495712   4.585665  27.780781
# City4    8.691427  10.608870  30.152606   4.955566  10.535630   8.306972
# City5   11.678511  22.079314  18.000996  14.239545  12.027992  -2.396619
# City6    6.647404  27.591927  33.785486  30.424524  22.135137  33.541324
# City7   31.707149  23.051087  23.321010  20.107148   0.076572   4.125558
# City8   -0.723147  22.204946   4.314669  12.382431  32.266177  24.437003
# City9   17.196892   0.810684  34.675189  32.627509  -4.742028  19.432381
# City10   6.566015  20.341324  10.425782   7.425293  14.847935   2.646440
#
#               Jul        Aug        Sep        Oct        Nov        Dec
# City1   29.167595   3.488647  21.646913  20.929303   2.714928  -2.247056
# ...

# %%
# Calculate the annual average temperature for each city
annual_avg_temp = df.mean(axis=1)

# annual average temperature for each city
print(annual_avg_temp)
# Out:
# City1     19.675863
# City2     20.885178
# City3     13.566125
# City4     11.832091
# City5     15.395938
# City6     23.930732
# City7     15.188713
# City8     17.081705
# City9     12.234395
# City10    16.471039
# dtype: float64

# %%
# City with the highest average temperature
city_highest_avg_temp = annual_avg_temp.idxmax()

# City with the lowest average temperature
city_lowest_avg_temp = annual_avg_temp.idxmin()

# Display the cities with the highest and lowest average temperatures
print(f"City with the highest average temperature: {city_highest_avg_temp}")
print(f"City with the lowest average temperature: {city_lowest_avg_temp}")
# Out:
# City with the highest average temperature: City6
# City with the lowest average temperature: City4

# %%
import matplotlib.pyplot as plt

# Plot the temperatures for all cities
plt.figure(figsize=(10, 6))

for city in df.index:
    plt.plot(df.columns, df.loc[city], label=city)

plt.title('Monthly Average Temperatures for Each City')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %%
# #Summary of Findings:

# 1. City with the Highest Average Temperature:
#     - The city with the highest average temperature is City6

# 2. City with the Lowest Average Temperature:
#     - The city with the lowest average temperature is City4

# 3. Interesting Trends:
#     - From the line plot of monthly temperatures, we can observe that some cities experience significant seasonal variations,
# with temperatures peaking in the summer months (June, July, and August) and dropping in the winter months (December, January, and February).
#     - Other cities may show relatively stable temperatures throughout the year, suggesting a more temperate or tropical climate.
#     - The bar plot of annual averages confirms that cities near the equator (typically warmer) have higher annual temperatures,
# while cities in higher latitudes (typically cooler) have lower annual temperatures.
