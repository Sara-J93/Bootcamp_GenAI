# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
#  0f5d06b2-8232-44ab-8cff-4e4d20933096.jpg
# '0-Religiousness-and-secularism (1).zip'
#  0-Religiousness-and-secularism.zip
#  14375aff-94b2-4f2e-a355-1b7391e70b6b.jpg
#  2016-07-08-PHOTO-00000005.jpg
#  7c64e28e-954a-4932-a732-164c175c5498.jpg
# 'Abstract 22-11-2019[17726] Sara.odt'
# 'Antoun Helal.gdoc'
#  Aquarius.docx
# 'Attestation de réussite.pdf'
# 'Attestation d’hebergement .gdoc'
# 'Attestation d’hebergement .pdf'
#  AttestationDroits.pdf
#  Attestation_locataire_204_RUE_CHAMPIONNET_75018_PARIS.pdf
# 'attestation Sara Jabali.docx'
# 'attestation Sara Jabali.gdoc'
# 'attestation Sara Jabali.pdf'
#  Azza
# 'BIA PORTABILITE.gdoc'
# 'BIA PORTABILITE.pdf'
# 'Blank 7.pages'
# 'Booking #1985890908.pdf'
# 'books 2.jpg'
#  books.jpg
# 'Books TONI.gdoc'
# 'Brève .docx'
#  Brochure.gdoc
#  CAF
# 'Chrome OS Cloud backup'
# 'Chrome Syncable FileSystem'
# 'Coffee Table Art Material'
# 'Colab Notebooks'
# 'Contrat Sara.pdf'
# 'Copy of Lettre de motivation linguistique.docx'
# ...

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks
# Out:
#  Brain.zip		     DailyChallengeW2D3.ipynb   ExercisesD3W4.ipynb
#  challenge1.ipynb	     DailyChallengeW2D5.ipynb   ExercisesDay4Week2.ipynb
#  challenge2.ipynb	     Exercise1+2+3w2d3.ipynb   'Flower Classification.zip'
#  challengepage1w2d3.ipynb    Exercise1.ipynb	        Foodie_Analysis.pptx
#  challengepage2w2d3.ipynb   'Exercise 2.ipynb'	        Foodie_Analysis_Presentation.pptx
#  ClassChallenge1D2W4.ipynb   Exercise3.ipynb	        HackathonD5W3.ipynb
#  ClassChallenge3D2W4.ipynb   Exercise4+5.ipynb	        MiniProjectW2.ipynb
#  DailyChallengeD1W3.ipynb    Exercise4w2d3.ipynb        MiniProjectW3.ipynb
#  DailyChallengeD1W4.ipynb    Exercises1+2+3D2W2.ipynb   NOTES_D1W3.ipynb
#  DailyChallengeD2W3.ipynb    Exercises4D2W2.ipynb       NOTES-D2W3.ipynb
#  DailyChallengeD2W4.ipynb    Exercises5D2W2.ipynb       NOTES-D3W3.ipynb
#  DailyChallengeD3W3.ipynb    Exercises6D2W2.ipynb       NOTES_plots_day4.ipynb
#  DailyChallengeD3W4.ipynb    ExercisesD1W3.ipynb        test.ipynb
# ...

# %%
! unzip /content/drive/MyDrive/Colab\ Notebooks/Brain.zip -d /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/Brain.zip
#   inflating: /content/drive/MyDrive/Colab Notebooks/metadata.csv

# %%
import os

dataset_path = "/content/drive/MyDrive/Colab Notebooks/"

# List the contents of the dataset directory
print("Contents of dataset folder:")
print(os.listdir(dataset_path))
# Out:
# Contents of dataset folder:
# ...

# %%
import zipfile
import os

# Define paths
zip_path = "/content/drive/MyDrive/Colab Notebooks/Brain.zip"  # Path to the ZIP file
extract_path = "/content/drive/MyDrive/Colab Notebooks/Brain_Tumor"  # Folder where it will be extracted

# Extract only if not already extracted
if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print(f"✅ Dataset extracted to: {extract_path}")
else:
    print(f"✅ Dataset already extracted at: {extract_path}")
# Out:
# ✅ Dataset extracted to: /content/drive/MyDrive/Colab Notebooks/Brain_Tumor

# %%
import os

dataset_path = "/content/drive/MyDrive/Colab Notebooks/Brain_Tumor"

# List the contents of the dataset directory
print("Contents of Brain_Tumor folder:", os.listdir(dataset_path))
# Out:
# Contents of Brain_Tumor folder: ['metadata.csv']

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define dataset path
dataset_path = "/content/drive/MyDrive/Colab Notebooks/Brain_Tumor"

# Set batch size and image size
batch_size = 5
img_size = (180, 180)

# Load Training Dataset (80% for training)
train_dataset = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,  # 20% for validation
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

# Load Validation Dataset (20% for validation)
validation_dataset = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

print("✅ Dataset loaded successfully!")
# Out:
# Found 0 files belonging to 0 classes.
# Using 0 files for training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-3f1913b7e016> in <cell line: 0>()
#       9
#      10 # Load Training Dataset (80% for training)
# ---> 11 train_dataset = image_dataset_from_directory(
#      12     dataset_path,
#      13     validation_split=0.2,  # 20% for validation
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     327         )
#     328         if not image_paths:
# --> 329             raise ValueError(
#     330                 f"No images found in directory {directory}. "
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Define dataset path
dataset_path = "/content/drive/MyDrive/Colab Notebooks/Brain_Tumor"

# Set batch size and image size
batch_size = 10
img_size = (180, 180)

# Load Training Dataset
train_dataset = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,  # 20% for validation
    subset="training",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)

# Load Validation Dataset
validation_dataset = image_dataset_from_directory(
    dataset_path,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 0 files belonging to 0 classes.
# Using 0 files for training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b9638ff5acad> in <cell line: 0>()
#      10
#      11 # Load Training Dataset
# ---> 12 train_dataset = image_dataset_from_directory(
#      13     dataset_path,
#      14     validation_split=0.2,  # 20% for validation
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/image_dataset_utils.py in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, pad_to_aspect_ratio, data_format, verbose)
#     327         )
#     328         if not image_paths:
# --> 329             raise ValueError(
#     330                 f"No images found in directory {directory}. "
# ...
